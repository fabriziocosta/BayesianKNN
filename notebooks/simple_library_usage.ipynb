# %% [markdown]
# # Simple library usage
#
# Load the wine dataset, split it, fit Bayesian model averaging with the default family registry, and evaluate the test set.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

from bayesian_model_averaging import BayesianModelAveragingClassifier

wine = load_wine()
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=7, stratify=y
)

# The default family registry is used automatically.
# n_estimators is set lower here to keep the example quick.
model = BayesianModelAveragingClassifier(n_estimators=40, random_state=7)
model.fit(X_train, y_train)

print(f"test accuracy: {model.score(X_test, y_test):.3f}")
print("family posterior shares:", model.get_model_masses()["family"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.datasets import load_wine
#       2 from sklearn.model_selection import train_test_split
# ----> 4 from bayesian_model_averaging import BayesianModelAveragingClassifier
#       6 wine = load_wine()
#       7 X, y = wine.data, wine.target
#
# ModuleNotFoundError: No module named 'bayesian_model_averaging'
